# %%
from amocrm_api import AmoOAuthClient
client = AmoOAuthClient(
    access_token="eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjI2NTdmYTdjZjBhYzg4NjlmMmJjNWEzNzEzMDEwYTAzYjYwMWY4ODRhMDE2NzczMTcwMzhmN2Q1YmM0MTkxMzBhOTc0NDNjZmY3MDU3YWIwIn0.....o7RpPR9A4ENLMNdz3pCTlOx4OC6P5C-u1taAWrV7v-uctxa-_qIiMocFMTO24-N_d9JrK2LqbAGGeRq6fAmVrQ_JkOGo4vr9VGKYaT7pe_sfKa4ba99TiHsCLUGqpZc21Gp6G8LZO4PPkHbC79klNYpEnq3J4ozr-vfjXkk9FTF_8NrW2QCU7RTohC2SQtnZ6cxVZ7k5JljKLRa6J9rFTvo5yRNLLdHyh3GuO80KOTBci08meyi_9zpzhk1YXnEBpvJoHLhDc6sQXHejE-2eJUL_sosZko9R6us2jBBgsxqB5qlCV6QmvLl3TEyLHYWIzNwWz6hhE20NpwzcXGhELw",
    refresh_token="eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjI2NTdmYTdjZjBhYzg4NjlmMmJjNWEzNzEzMDEwYTAzYjYwMWY4ODRhMDE2NzczMTcwMzhmN2Q1YmM0MTkxMzBhOTc0NDNjZmY3MDU3YWIwIn0.....o7RpPR9A4ENLMNdz3pCTlOx4OC6P5C-u1taAWrV7v-uctxa-_qIiMocFMTO24-N_d9JrK2LqbAGGeRq6fAmVrQ_JkOGo4vr9VGKYaT7pe_sfKa4ba99TiHsCLUGqpZc21Gp6G8LZO4PPkHbC79klNYpEnq3J4ozr-vfjXkk9FTF_8NrW2QCU7RTohC2SQtnZ6cxVZ7k5JljKLRa6J9rFTvo5yRNLLdHyh3GuO80KOTBci08meyi_9zpzhk1YXnEBpvJoHLhDc6sQXHejE-2eJUL_sosZko9R6us2jBBgsxqB5qlCV6QmvLl3TEyLHYWIzNwWz6hhE20NpwzcXGhELw",
    crm_url="https://tnamo.amocrm.ru",
    client_id="c6065b67-4f74-4dd1-852b-d81359224c86",
    client_secret="ZVZpsmcF5IcUgYdas0EkYGU8Cn0JOhlpkZq8V3nPW8c1cIYPtdAHmqpCwgGTskDM",
    redirect_uri="http://localhost:8000/callback"
)

# %%
# Инициализация переменных для пагинации
from pprint import pprint


page = 1
limit = 10
all_leads = []

# while True:
# Получение лидов с текущей страницы
leads = client.get_leads(limit=limit, page=page)

# Добавление полученных лидов в общий список
all_leads.extend(leads['_embedded']['leads'])

# Если на текущей странице меньше лидов, чем limit, значит это последняя страница


# Переход к следующей странице
page += 1

pprint(all_leads[0])
# # Вывод информации о лидах
# for lead in all_leads:
#     print(f"ID лида: {lead['id']}, Название: {lead['name']}, Сумма: {lead['price']}, ID воронки: {lead['pipeline_id']}")
# Out:
# {'_embedded': {'companies': [{'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/companies/64707895?limit=10&page=1'}},
#                               'id': 64707895}],
#                'tags': [{'color': None, 'id': 481395, 'name': 'tilda'}]},
#  '_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/30902809?limit=10&page=1'}},
#  'account_id': 25031677,
#  'closed_at': 1670000172,
#  'closest_task_at': None,
#  'created_at': 1636531072,
#  'created_by': 0,
#  'custom_fields_values': [{'field_code': 'CITY',
#                            'field_id': 680243,
#                            'field_name': 'Город',
#                            'field_type': 'textarea',
#                            'values': [{'value': 'Москва'}]},
#                           {'field_code': 'FORMNAME',
#                            'field_id': 680251,
#                            'field_name': 'FORMNAME',
#                            'field_type': 'textarea',
#                            'values': [{'value': 'Попап Главная'}]},
#                           {'field_code': 'UTM_REFERRER',
#                            'field_id': 906933,
#                            'field_name': 'utm_referrer',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': 'https://imprice.ru/'}]}],
#  'group_id': 0,
#  'id': 30902809,
#  'is_deleted': False,
#  'labor_cost': None,
#  'loss_reason_id': 2352769,
#  'name': 'Заявка #2489689:2661521941 с формы: Попап Главная отправлена с '
#          '[imprice.ru]',
#  'pipeline_id': 1657279,
#  'price': 190000,
#  'responsible_user_id': 3306442,
#  'score': None,
#  'status_id': 143,
#  'updated_at': 1670000438,
#  'updated_by': 3306442}

# %%
lead = client.get_lead(40731951)
pprint(lead)
# Out:
# {'_embedded': {'companies': [{'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/companies/72055585?page=1&limit=250'}},
#                               'id': 72055585}],
#                'tags': [{'color': None, 'id': 481395, 'name': 'tilda'}]},
#  '_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/40731951?page=1&limit=250'}},
#  'account_id': 25031677,
#  'closed_at': None,
#  'closest_task_at': None,
#  'created_at': 1757942456,
#  'created_by': 0,
#  'custom_fields_values': [{'field_code': 'CHECKBOX',
#                            'field_id': 957451,
#                            'field_name': 'CHECKBOX',
#                            'field_type': 'textarea',
#                            'values': [{'value': 'yes'}]},
#                           {'field_code': None,
#                            'field_id': 956971,
#                            'field_name': 'Источник',
#                            'field_type': 'select',
#                            'values': [{'enum_code': None,
#                                        'enum_id': 4232987,
#                                        'value': 'Яндекс.Директ'}]},
#                           {'field_code': 'TRANID',
#                            'field_id': 956973,
#                            'field_name': 'TRANID',
#                            'field_type': 'textarea',
#                            'values': [{'value': '2489689:7775512773'}]},
#                           {'field_code': 'UTM_SOURCE',
#                            'field_id': 680335,
#                            'field_name': 'UTM_SOURCE',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': 'yandex'}]},
#                           {'field_code': 'UTM_MEDIUM',
#                            'field_id': 680337,
#                            'field_name': 'UTM_MEDIUM',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': 'cpc'}]},
#                           {'field_code': 'UTM_CAMPAIGN',
#                            'field_id': 680339,
#                            'field_name': 'UTM_CAMPAIGN',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': '118746608'}]},
#                           {'field_code': 'UTM_CONTENT',
#                            'field_id': 906931,
#                            'field_name': 'utm_content',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': '16902958823'}]},
#                           {'field_code': 'UTM_TERM',
#                            'field_id': 906929,
#                            'field_name': 'utm_term',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': '---autotargeting'}]},
#                           {'field_code': '_YM_UID',
#                            'field_id': 906935,
#                            'field_name': '_ym_uid',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': '1756734791293149950'}]},
#                           {'field_code': 'YCLID',
#                            'field_id': 906957,
#                            'field_name': 'yclid',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': '10953969518260518911'}]},
#                           {'field_code': 'FORMNAME',
#                            'field_id': 680251,
#                            'field_name': 'FORMNAME',
#                            'field_type': 'textarea',
#                            'values': [{'value': 'Телеграм-бот'}]},
#                           {'field_code': 'FORMID',
#                            'field_id': 956975,
#                            'field_name': 'FORMID',
#                            'field_type': 'textarea',
#                            'values': [{'value': 'form955166286'}]},
#                           {'field_code': 'REFERER',
#                            'field_id': 936011,
#                            'field_name': 'REFERER',
#                            'field_type': 'url',
#                            'values': [{'value': 'https://imprice.ru/repricer?utm_source=yandex&utm_medium=cpc&utm_campaign=118746608&utm_content=16902958823&utm_term=---autotargeting&yclid=10953969518260518911#%21%2Ftab%2F955165886-2'}]},
#                           {'field_code': 'UTM_REFERRER',
#                            'field_id': 906933,
#                            'field_name': 'utm_referrer',
#                            'field_type': 'tracking_data',
#                            'values': [{'value': 'https://imprice.ru/repricer?utm_source=yandex&utm_medium=cpc&utm_campaign=118746608&utm_content=16902958823&utm_term=---autotargeting&yclid=10953969518260518911#trial'}]}],
#  'group_id': 0,
#  'id': 40731951,
#  'is_deleted': False,
#  'labor_cost': None,
#  'loss_reason_id': None,
#  'name': 'Телеграм-бот - заявка #2489689:7775512773 отправлена с [imprice.ru]',
#  'pipeline_id': 9135578,
#  'price': 0,
#  'responsible_user_id': 12009022,
#  'score': None,
#  'status_id': 73457202,
#  'updated_at': 1758184746,
#  'updated_by': 12638730}

# %%
pipeline = client.get_pipeline(9135578)

pprint(pipeline)
# Out:
# {'_embedded': {'statuses': [{'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457198'}},
#                              'account_id': 25031677,
#                              'color': '#c1c1c1',
#                              'id': 73457198,
#                              'is_editable': False,
#                              'name': 'Неразобранное',
#                              'pipeline_id': 9135578,
#                              'sort': 10,
#                              'type': 1},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/75891786'}},
#                              'account_id': 25031677,
#                              'color': '#ffdbdb',
#                              'id': 75891786,
#                              'is_editable': True,
#                              'name': 'Телеграм-бот',
#                              'pipeline_id': 9135578,
#                              'sort': 20,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457202'}},
#                              'account_id': 25031677,
#                              'color': '#ff8f92',
#                              'id': 73457202,
#                              'is_editable': True,
#                              'name': 'Квалификация',
#                              'pipeline_id': 9135578,
#                              'sort': 30,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457206'}},
#                              'account_id': 25031677,
#                              'color': '#ffce5a',
#                              'id': 73457206,
#                              'is_editable': True,
#                              'name': 'Назначение ДЕМО',
#                              'pipeline_id': 9135578,
#                              'sort': 40,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457618'}},
#                              'account_id': 25031677,
#                              'color': '#fffd7f',
#                              'id': 73457618,
#                              'is_editable': True,
#                              'name': 'Ожидаем решения',
#                              'pipeline_id': 9135578,
#                              'sort': 50,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/74332950'}},
#                              'account_id': 25031677,
#                              'color': '#99ccff',
#                              'id': 74332950,
#                              'is_editable': True,
#                              'name': 'Ожидаем подключения',
#                              'pipeline_id': 9135578,
#                              'sort': 60,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457282'}},
#                              'account_id': 25031677,
#                              'color': '#deff81',
#                              'id': 73457282,
#                              'is_editable': True,
#                              'name': 'Тестовый период',
#                              'pipeline_id': 9135578,
#                              'sort': 70,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457210'}},
#                              'account_id': 25031677,
#                              'color': '#d6eaff',
#                              'id': 73457210,
#                              'is_editable': True,
#                              'name': 'Подготовка КП + оплата',
#                              'pipeline_id': 9135578,
#                              'sort': 80,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457622'}},
#                              'account_id': 25031677,
#                              'color': '#e6e8ea',
#                              'id': 73457622,
#                              'is_editable': True,
#                              'name': 'Отложено (прогрев)',
#                              'pipeline_id': 9135578,
#                              'sort': 90,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/73457438'}},
#                              'account_id': 25031677,
#                              'color': '#eb93ff',
#                              'id': 73457438,
#                              'is_editable': True,
#                              'name': 'Подключен',
#                              'pipeline_id': 9135578,
#                              'sort': 100,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/142'}},
#                              'account_id': 25031677,
#                              'color': '#CCFF66',
#                              'id': 142,
#                              'is_editable': False,
#                              'name': 'Успешно реализовано',
#                              'pipeline_id': 9135578,
#                              'sort': 10000,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578/statuses/143'}},
#                              'account_id': 25031677,
#                              'color': '#D5D8DB',
#                              'id': 143,
#                              'is_editable': False,
#                              'name': 'Закрыто и не реализовано',
#                              'pipeline_id': 9135578,
#                              'sort': 11000,
#                              'type': 0}]},
#  '_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/9135578'}},
#  'account_id': 25031677,
#  'id': 9135578,
#  'is_archive': False,
#  'is_main': False,
#  'is_unsorted_on': True,
#  'name': 'Воронка Репрайсер',
#  'sort': 5}

# %%
pipeline = client.get_pipeline(1657279)

pprint(pipeline)
# Out:
# {'_embedded': {'statuses': [{'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/25031683'}},
#                              'account_id': 25031677,
#                              'color': '#c1c1c1',
#                              'id': 25031683,
#                              'is_editable': False,
#                              'name': 'Неразобранное',
#                              'pipeline_id': 1657279,
#                              'sort': 10,
#                              'type': 1},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/53795562'}},
#                              'account_id': 25031677,
#                              'color': '#ff8f92',
#                              'id': 53795562,
#                              'is_editable': True,
#                              'name': 'НЕДОЗВОН',
#                              'pipeline_id': 1657279,
#                              'sort': 20,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/25038418'}},
#                              'account_id': 25031677,
#                              'color': '#ffce5a',
#                              'id': 25038418,
#                              'is_editable': True,
#                              'name': 'Бриф',
#                              'pipeline_id': 1657279,
#                              'sort': 30,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/25031689'}},
#                              'account_id': 25031677,
#                              'color': '#ffff99',
#                              'id': 25031689,
#                              'is_editable': True,
#                              'name': 'Согласование ДЕМО',
#                              'pipeline_id': 1657279,
#                              'sort': 40,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/25031695'}},
#                              'account_id': 25031677,
#                              'color': '#f3beff',
#                              'id': 25031695,
#                              'is_editable': True,
#                              'name': 'Стратегия ценообразования и КП',
#                              'pipeline_id': 1657279,
#                              'sort': 50,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/26029843'}},
#                              'account_id': 25031677,
#                              'color': '#87f2c0',
#                              'id': 26029843,
#                              'is_editable': True,
#                              'name': 'Согласование условий',
#                              'pipeline_id': 1657279,
#                              'sort': 60,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/34684186'}},
#                              'account_id': 25031677,
#                              'color': '#99ccff',
#                              'id': 34684186,
#                              'is_editable': True,
#                              'name': 'Отложено',
#                              'pipeline_id': 1657279,
#                              'sort': 70,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/60958794'}},
#                              'account_id': 25031677,
#                              'color': '#ffc8c8',
#                              'id': 60958794,
#                              'is_editable': True,
#                              'name': 'Прогрев ПОСЛЕ ОТКАЗА',
#                              'pipeline_id': 1657279,
#                              'sort': 80,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/34666402'}},
#                              'account_id': 25031677,
#                              'color': '#ccc8f9',
#                              'id': 34666402,
#                              'is_editable': True,
#                              'name': 'Подписание договора',
#                              'pipeline_id': 1657279,
#                              'sort': 90,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/46206286'}},
#                              'account_id': 25031677,
#                              'color': '#99ccff',
#                              'id': 46206286,
#                              'is_editable': True,
#                              'name': 'Проект в работе',
#                              'pipeline_id': 1657279,
#                              'sort': 100,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/79111294'}},
#                              'account_id': 25031677,
#                              'color': '#fffd7f',
#                              'id': 79111294,
#                              'is_editable': True,
#                              'name': 'ПАРТНЕРСТВО',
#                              'pipeline_id': 1657279,
#                              'sort': 110,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/79111298'}},
#                              'account_id': 25031677,
#                              'color': '#e6e8ea',
#                              'id': 79111298,
#                              'is_editable': True,
#                              'name': 'МОНИТОРИНГ',
#                              'pipeline_id': 1657279,
#                              'sort': 120,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/142'}},
#                              'account_id': 25031677,
#                              'color': '#CCFF66',
#                              'id': 142,
#                              'is_editable': False,
#                              'name': 'Проект реализован',
#                              'pipeline_id': 1657279,
#                              'sort': 10000,
#                              'type': 0},
#                             {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279/statuses/143'}},
#                              'account_id': 25031677,
#                              'color': '#D5D8DB',
#                              'id': 143,
#                              'is_editable': False,
#                              'name': 'Закрыто и не реализовано',
#                              'pipeline_id': 1657279,
#                              'sort': 11000,
#                              'type': 0}]},
#  '_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/leads/pipelines/1657279'}},
#  'account_id': 25031677,
#  'id': 1657279,
#  'is_archive': False,
#  'is_main': True,
#  'is_unsorted_on': True,
#  'name': 'Основная Воронка',
#  'sort': 1}

# %%
users = client.get_users(1, 250)

pprint(users)
# Out:
# {'_embedded': {'users': [{'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/3306442/?page=1&limit=250'}},
#                           'email': 'tn@1spectr.com',
#                           'id': 3306442,
#                           'lang': 'ru',
#                           'name': 'Цуканов Никита',
#                           'rights': {'catalog_access': True,
#                                      'catalog_rights': None,
#                                      'companies': {'add': 'A',
#                                                    'delete': 'A',
#                                                    'edit': 'A',
#                                                    'export': 'A',
#                                                    'view': 'A'},
#                                      'contacts': {'add': 'A',
#                                                   'delete': 'A',
#                                                   'edit': 'A',
#                                                   'export': 'A',
#                                                   'view': 'A'},
#                                      'custom_fields_rights': None,
#                                      'files_access': True,
#                                      'group_id': 0,
#                                      'is_active': True,
#                                      'is_admin': True,
#                                      'is_free': False,
#                                      'leads': {'add': 'A',
#                                                'delete': 'A',
#                                                'edit': 'A',
#                                                'export': 'A',
#                                                'view': 'A'},
#                                      'mail_access': True,
#                                      'oper_day_reports_view_access': False,
#                                      'oper_day_user_tracking': False,
#                                      'role_id': None,
#                                      'status_rights': [{'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 25031683},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 53344754},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 65947162},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8252498,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 67361730},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 9135578,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 73457198}],
#                                      'tasks': {'delete': 'A', 'edit': 'A'}}},
#                          {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/3306448/?page=1&limit=250'}},
#                           'email': 'sev@1spectr.com',
#                           'id': 3306448,
#                           'lang': 'ru',
#                           'name': 'Евгений Сергеев',
#                           'rights': {'catalog_access': True,
#                                      'catalog_rights': None,
#                                      'companies': {'add': 'A',
#                                                    'delete': 'A',
#                                                    'edit': 'A',
#                                                    'export': 'A',
#                                                    'view': 'A'},
#                                      'contacts': {'add': 'A',
#                                                   'delete': 'A',
#                                                   'edit': 'A',
#                                                   'export': 'A',
#                                                   'view': 'A'},
#                                      'custom_fields_rights': None,
#                                      'files_access': True,
#                                      'group_id': 0,
#                                      'is_active': True,
#                                      'is_admin': True,
#                                      'is_free': False,
#                                      'leads': {'add': 'A',
#                                                'delete': 'A',
#                                                'edit': 'A',
#                                                'export': 'A',
#                                                'view': 'A'},
#                                      'mail_access': True,
#                                      'oper_day_reports_view_access': False,
#                                      'oper_day_user_tracking': False,
#                                      'role_id': None,
#                                      'status_rights': [{'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 25031683},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 53344754},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 65947162},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8252498,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 67361730},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 9135578,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 73457198}],
#                                      'tasks': {'delete': 'A', 'edit': 'A'}}},
#                          {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/12009022/?page=1&limit=250'}},
#                           'email': 'erm@imprice.ai',
#                           'id': 12009022,
#                           'lang': 'ru',
#                           'name': 'Михаил Еремичев',
#                           'rights': {'catalog_access': False,
#                                      'catalog_rights': None,
#                                      'companies': {'add': 'A',
#                                                    'delete': 'M',
#                                                    'edit': 'A',
#                                                    'export': 'D',
#                                                    'view': 'A'},
#                                      'contacts': {'add': 'A',
#                                                   'delete': 'M',
#                                                   'edit': 'A',
#                                                   'export': 'D',
#                                                   'view': 'A'},
#                                      'custom_fields_rights': None,
#                                      'files_access': False,
#                                      'group_id': 0,
#                                      'is_active': True,
#                                      'is_admin': False,
#                                      'is_free': False,
#                                      'leads': {'add': 'A',
#                                                'delete': 'M',
#                                                'edit': 'A',
#                                                'export': 'D',
#                                                'view': 'A'},
#                                      'mail_access': False,
#                                      'oper_day_reports_view_access': False,
#                                      'oper_day_user_tracking': False,
#                                      'role_id': 959262,
#                                      'status_rights': [{'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 142},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 25031683},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 46206286},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 53344754},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 65947162},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8252498,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 67361730},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 9135578,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 73457198}],
#                                      'tasks': {'delete': 'A', 'edit': 'A'}}},
#                          {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/12012534/?page=1&limit=250'}},
#                           'email': 'uvt@imprice.ai',
#                           'id': 12012534,
#                           'lang': 'ru',
#                           'name': 'Татьяна Уварова',
#                           'rights': {'catalog_access': True,
#                                      'catalog_rights': None,
#                                      'companies': {'add': 'A',
#                                                    'delete': 'A',
#                                                    'edit': 'A',
#                                                    'export': 'A',
#                                                    'view': 'A'},
#                                      'contacts': {'add': 'A',
#                                                   'delete': 'A',
#                                                   'edit': 'A',
#                                                   'export': 'A',
#                                                   'view': 'A'},
#                                      'custom_fields_rights': None,
#                                      'files_access': True,
#                                      'group_id': 0,
#                                      'is_active': True,
#                                      'is_admin': True,
#                                      'is_free': False,
#                                      'leads': {'add': 'A',
#                                                'delete': 'A',
#                                                'edit': 'A',
#                                                'export': 'A',
#                                                'view': 'A'},
#                                      'mail_access': True,
#                                      'oper_day_reports_view_access': False,
#                                      'oper_day_user_tracking': False,
#                                      'role_id': None,
#                                      'status_rights': [{'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 25031683},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 53344754},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8252498,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 67361730},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 65947162},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 9135578,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 73457198}],
#                                      'tasks': {'delete': 'A', 'edit': 'A'}}},
#                          {'_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/12638730/?page=1&limit=250'}},
#                           'email': 'asa@imprice.ai',
#                           'id': 12638730,
#                           'lang': 'ru',
#                           'name': 'Александр Астафьев',
#                           'rights': {'catalog_access': False,
#                                      'catalog_rights': None,
#                                      'companies': {'add': 'A',
#                                                    'delete': 'D',
#                                                    'edit': 'M',
#                                                    'export': 'D',
#                                                    'view': 'A'},
#                                      'contacts': {'add': 'A',
#                                                   'delete': 'D',
#                                                   'edit': 'M',
#                                                   'export': 'D',
#                                                   'view': 'A'},
#                                      'custom_fields_rights': None,
#                                      'files_access': False,
#                                      'group_id': 0,
#                                      'is_active': True,
#                                      'is_admin': False,
#                                      'is_free': False,
#                                      'leads': {'add': 'A',
#                                                'delete': 'D',
#                                                'edit': 'A',
#                                                'export': 'D',
#                                                'view': 'A'},
#                                      'mail_access': False,
#                                      'oper_day_reports_view_access': False,
#                                      'oper_day_user_tracking': False,
#                                      'role_id': 1042538,
#                                      'status_rights': [{'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 142},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 143},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 25031683},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 25031689},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 25031695},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 25038418},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 26029843},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 34666402},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 34684186},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 46206286},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53795562},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 1657279,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 60958794},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 142},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 143},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53344754},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53344758},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53344762},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53345070},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 6175070,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 53346014},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 142},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 143},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 65947162},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 65947166},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 65947170},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8047562,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'export': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 65947174},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 8252498,
#                                                         'rights': {'delete': 'D',
#                                                                    'edit': 'D',
#                                                                    'view': 'D'},
#                                                         'status_id': 67361730},
#                                                        {'entity_type': 'leads',
#                                                         'pipeline_id': 9135578,
#                                                         'rights': {'delete': 'A',
#                                                                    'edit': 'A',
#                                                                    'view': 'A'},
#                                                         'status_id': 73457198}],
#                                      'tasks': {'delete': 'D', 'edit': 'A'}}}]},
#  '_links': {'self': {'href': 'https://tnamo.amocrm.ru/api/v4/users/?page=1&limit=250'}},
#  '_page': 1,
#  '_page_count': 1,
#  '_total_items': 5}
